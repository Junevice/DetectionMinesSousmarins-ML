# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('sonar.all-data.csv', header=None)

# %% [markdown]
# # Renommer toutes les colonnes f(i) pour chaque mesure et isMine

# %%
df.columns = ['f{}'.format(i) for i in range(df.shape[1])]

# %%
df
# Out:
#       f0   f1   f2   f3   f4   f5   f6   f7   f8   f9  ...  f51  f52  f53  \
# 0   0.02 0.04 0.04 0.02 0.10 0.10 0.15 0.16 0.31 0.21  ... 0.00 0.01 0.02
# 1   0.05 0.05 0.08 0.07 0.12 0.26 0.22 0.35 0.33 0.29  ... 0.01 0.01 0.00
# 2   0.03 0.06 0.11 0.11 0.10 0.23 0.24 0.38 0.56 0.62  ... 0.02 0.02 0.01
# 3   0.01 0.02 0.06 0.02 0.02 0.04 0.11 0.13 0.06 0.13  ... 0.01 0.00 0.01
# 4   0.08 0.07 0.05 0.04 0.06 0.06 0.12 0.25 0.36 0.45  ... 0.00 0.01 0.01
# ..   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 203 0.02 0.03 0.02 0.02 0.04 0.16 0.20 0.17 0.23 0.27  ... 0.01 0.01 0.02
# 204 0.03 0.01 0.03 0.06 0.08 0.10 0.10 0.10 0.10 0.22  ... 0.01 0.01 0.01
# 205 0.05 0.04 0.02 0.03 0.04 0.12 0.13 0.12 0.13 0.25  ... 0.02 0.00 0.01
# 206 0.03 0.04 0.05 0.06 0.02 0.14 0.15 0.11 0.19 0.24  ... 0.01 0.00 0.01
# 207 0.03 0.04 0.01 0.03 0.02 0.03 0.07 0.14 0.18 0.24  ... 0.01 0.01 0.00
#
#      f54  f55  f56  f57  f58  f59  f60
# 0   0.01 0.02 0.02 0.01 0.01 0.00    R
# ...

# %%
df = df.replace('R',0)
df = df.replace('M',1)

# %%
df = df.rename(columns={'f60': "isMine"})

# %%
df
# Out:
#       f0   f1   f2   f3   f4   f5   f6   f7   f8   f9  ...  f51  f52  f53  \
# 0   0.02 0.04 0.04 0.02 0.10 0.10 0.15 0.16 0.31 0.21  ... 0.00 0.01 0.02
# 1   0.05 0.05 0.08 0.07 0.12 0.26 0.22 0.35 0.33 0.29  ... 0.01 0.01 0.00
# 2   0.03 0.06 0.11 0.11 0.10 0.23 0.24 0.38 0.56 0.62  ... 0.02 0.02 0.01
# 3   0.01 0.02 0.06 0.02 0.02 0.04 0.11 0.13 0.06 0.13  ... 0.01 0.00 0.01
# 4   0.08 0.07 0.05 0.04 0.06 0.06 0.12 0.25 0.36 0.45  ... 0.00 0.01 0.01
# ..   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 203 0.02 0.03 0.02 0.02 0.04 0.16 0.20 0.17 0.23 0.27  ... 0.01 0.01 0.02
# 204 0.03 0.01 0.03 0.06 0.08 0.10 0.10 0.10 0.10 0.22  ... 0.01 0.01 0.01
# 205 0.05 0.04 0.02 0.03 0.04 0.12 0.13 0.12 0.13 0.25  ... 0.02 0.00 0.01
# 206 0.03 0.04 0.05 0.06 0.02 0.14 0.15 0.11 0.19 0.24  ... 0.01 0.00 0.01
# 207 0.03 0.04 0.01 0.03 0.02 0.03 0.07 0.14 0.18 0.24  ... 0.01 0.01 0.00
#
#      f54  f55  f56  f57  f58  f59  isMine
# ...

# %% [markdown]
# # Afficher corrélation pour trouver quelles plages de fréquences sont les plus utiles à la détection de mines

# %%
import seaborn as sns

fig, ax = plt.subplots(figsize=(20,20))         
sns.heatmap(df.corr(), annot=True , ax = ax , cmap = 'RdYlGn', center=0)
# Out:
# <AxesSubplot:>

# %%
corr = df.corr()
good_corr = corr[corr['isMine']>0.4]

new_df = pd.DataFrame()
for column in list(good_corr.index):
    new_df[column] = df[column]

new_df
# Out:
#      f10  isMine
# 0   0.16       0
# 1   0.49       0
# 2   0.63       0
# 3   0.09       0
# 4   0.42       0
# ..   ...     ...
# 203 0.31       1
# 204 0.31       1
# 205 0.27       1
# 206 0.29       1
# 207 0.27       1
#
# [208 rows x 2 columns]

# %% [markdown]
# Cette approche n'est pas bonne. Lorsque je tri mon DataFrame en utilisant uniquement les valeurs les plus corrélées à isMine, je perds des points de score :
#
# 	Accuracy	Balanced Accuracy	ROC AUC	F1 Score	Time Taken
#
# - >  Sans => KNeighborsClassifier	0.90	0.91	0.91	0.91	0.05
# - > 0.02 => SVC	0.88	0.88	0.88	0.88	0.01
# - > 0.05 => SVC	0.88	0.88	0.88	0.88	0.01
# - > 0.1 => KNeighborsClassifier	0.88	0.88	0.88	0.88	0.05
# - > 0.2 => ExtraTreesClassifier	0.81	0.81	0.81	0.81	0.10
# - > 0.3 => NearestCentroid	0.81	0.82	0.82	0.81	0.02
# - > 0.4 => LGBMClassifier 0.74	0.74	0.74	0.74	0.03
#
#
# On reste donc sans tri préalable en fonction de la correlation sur ce point.

# %% [markdown]
# # PCA and Standardisation

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_scaled = sc.fit_transform(df.drop(['isMine'], axis=1))

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 16)
pca.fit(X_scaled)
print("Cumulative Variances (Percentage):")
print(np.cumsum(pca.explained_variance_ratio_ * 100))
components = len(pca.explained_variance_ratio_)
print(f'Number of components: {components}')
# Make the scree plot
plt.plot(range(1, components + 1), np.cumsum(pca.explained_variance_ratio_ * 100))
plt.xlabel("Number of components")
plt.ylabel("Explained variance (%)")
# Out:
# Cumulative Variances (Percentage):
# [20.34655665 39.24377302 47.79376154 53.47295189 58.48003183 62.54502706
#  65.82401887 68.87048471 71.43644569 73.927548   76.00282822 77.90481818
#  79.65179775 81.19028196 82.61807898 83.9790376 ]
# Number of components: 16
# Text(0, 0.5, 'Explained variance (%)')

# %% [markdown]
# # Model

# %%
y = df['isMine']
# X = df.drop(['isMine'], axis=1)

X_pca = pca.transform(X_scaled)
print(X_pca.shape)
print(X_pca)
# Out:
# (208, 16)
# [[ 1.92116817 -1.37089312 -1.66647597 ... -0.40620394  0.58873294
#   -1.51372284]
#  [-0.48012458  7.58638801 -1.27573428 ... -0.92696531  0.96844609
#   -0.58661905]
#  [ 3.8592282   6.43986016 -0.03063464 ... -1.44181813  1.40523419
#    2.02500829]
#  ...
#  [-2.29321041 -2.75544556  2.38846736 ... -0.48918458 -0.74026144
#   -0.26247742]
#  [-3.11446433 -1.85054952  2.42048603 ...  0.19087395 -0.54016414
#   -0.0317542 ]
#  [-3.23862419 -2.27709396  1.70612762 ...  1.37194654  0.88136569
#    1.01105777]]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.2, random_state=42)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (166, 16) (42, 16) (166,) (42,)

# %%
from lazypredict.Supervised import LazyClassifier

clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:00<00:00, 44.03it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# ExtraTreesClassifier               0.95               0.96     0.96      0.95
# XGBClassifier                      0.90               0.91     0.91      0.91
# SVC                                0.90               0.91     0.91      0.91
# NuSVC                              0.90               0.91     0.91      0.91
# RandomForestClassifier             0.86               0.88     0.88      0.86
# LGBMClassifier                     0.86               0.87     0.87      0.86
# LabelSpreading                     0.83               0.85     0.85      0.84
# LabelPropagation                   0.83               0.85     0.85      0.84
# DecisionTreeClassifier             0.83               0.84     0.84      0.84
# ...

# %% [markdown]
# Sans PCA (ni rien d'autre) le meilleur serait le
# KNeighborsClassifier	0.90	0.91	0.91	0.91	0.05
#
# Avec PCA (9 components) nous avons
# ExtraTreesClassifier	0.93	0.94	0.94	0.93	0.08
#
# Avec PCA (11 components)
# XGBClassifier	0.90	0.92	0.92	0.91	0.05
#
# Avec PCA (14 components) NuSVC	 0.90	0.92	0.92	0.91	0.00
#
# Avec PCA (16 components) ExtraTreesClassifier	0.95	0.96	0.96	0.95	0.08
#
# Avec PCA (18 components) ExtraTreesClassifier	0.95	0.95	0.95	0.95	0.09

# %%
from sklearn.ensemble import ExtraTreesClassifier

clf = ExtraTreesClassifier(n_estimators=100, random_state=0)
clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [821], in <cell line: 3>()
#       1 from sklearn.ensemble import ExtraTreesClassifier
# ----> 3 clf = ExtraTreesClassifier(n_estimators=100, random_state=0,shuffle=True)
#       4 clf.fit(X_train, y_train)
#
# TypeError: __init__() got an unexpected keyword argument 'shuffle'

# %%
clf.score(X_test, y_test)
# Out:
# 0.9761904761904762

# %%
clf.score(X_train, y_train)
# Out:
# 1.0

# %%
from sklearn.model_selection import KFold, cross_val_score
from sklearn.model_selection import GridSearchCV
seed = 0

cv = KFold(n_splits=10, random_state=seed, shuffle=True)
parameters = {
    'n_estimators' : [100, 200, 500],
    'min_samples_leaf': [5,10,20],
    'max_features': [2,3,4]

}
clf = GridSearchCV(ExtraTreesClassifier(), param_grid=parameters, cv=cv)

# %%
clf.fit(X_train, y_train)
print(clf.best_estimator_)
# Out:
# ExtraTreesClassifier(max_features=3, min_samples_leaf=5)

# %%
clf.score(X_test, y_test)
# Out:
# 0.8809523809523809
